# %%
from pandas import read_csv
import pandas as pd
import numpy as np
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
import seaborn as sns

# %%
df=pd.read_excel('C:/Users/stefa/Desktop/Romania_RNN.xlsx')
df
# Out:
#            Lat      Lon  Depth  Previous  Mag
# 0      46.5000  27.3000    9.9         0  3.2
# 1      46.0000  21.2000    9.9         0  4.5
# 2      46.5000  27.3000    9.9         0  5.5
# 3      44.3000  26.3000    9.9         0  2.6
# 4      45.0000  24.1000    9.9         0  4.2
# ...        ...      ...    ...       ...  ...
# 30499  46.0443  22.8680    5.9        35  1.9
# 30500  46.8633  22.8872    5.0        35  1.9
# 30501  45.6367  27.9550   20.3        35  1.9
# 30502  45.7725  26.6335   74.3        35  3.0
# 30503  45.5518  26.4571  110.7        35  3.2
#
# [30504 rows x 5 columns]

# %% [markdown]
# IMPORTANCE SCORE PENTRU MODELUL PREVIOUS (DATE ROMANIA)

# %%
array = df.values
X = array[:,0:4]
Y = array[:, 4]
# feature extraction
test = SelectKBest(score_func=f_classif, k= 'all')
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=4)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:4,:])
# Out:
# [ 14.2013  56.0256 862.9582 211.1832]
# [[46.5 27.3  9.9  0. ]
#  [46.  21.2  9.9  0. ]
#  [46.5 27.3  9.9  0. ]
#  [44.3 26.3  9.9  0. ]]

# %%
df1=pd.read_csv('C:/Users/stefa/Downloads/Global_previous.csv')
df1
# Out:
#            Lat      Lon  Depth  Previous  Mag
# 0       57.090 -153.480    0.0         0  8.3
# 1       60.000 -135.000    0.0         0  7.1
# 2       52.000 -160.000    0.0         0  6.6
# 3       51.450 -171.020    0.0         0  7.8
# 4       52.380 -167.450    0.0         0  7.8
# ...        ...      ...    ...       ...  ...
# 363065  16.625  -98.755   35.0         0  4.0
# 363066  52.788  171.431   48.4         0  4.5
# 363067  14.083  -92.184   62.4         0  4.4
# 363068 -61.596  154.288   10.0         0  5.2
# 363069  -6.950  154.485   52.8         0  4.6
#
# [363070 rows x 5 columns]

# %% [markdown]
# IMPORTANCE SCORE PENTRU MODELUL PREVIOUS (DATE GLOBALE)

# %%
array = df1.values
X = array[:,0:4]
Y = array[:, 4]
# feature extraction
test = SelectKBest(score_func=f_classif, k= 'all')
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=4)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:4,:])
# Out:
# [40.2004 35.763   6.1618 12.6269]
# [[  57.09 -153.48    0.      0.  ]
#  [  60.   -135.      0.      0.  ]
#  [  52.   -160.      0.      0.  ]
#  [  51.45 -171.02    0.      0.  ]]

# %%
df2 = pd.read_csv('C:/Users/stefa/Downloads/Fe.csv')
df2
# Out:
#            lat     long  depth   Days   Mw
# 0      46.5000  27.3000    9.9      0  3.2
# 1      46.0000  21.2000    9.9     26  4.5
# 2      46.5000  27.3000    9.9     28  5.5
# 3      44.3000  26.3000    9.9    170  2.6
# 4      45.0000  24.1000    9.9    171  4.2
# ...        ...      ...    ...    ...  ...
# 30499  46.0443  22.8680    5.9  44282  1.9
# 30500  46.8633  22.8872    5.0  44282  1.9
# 30501  45.6367  27.9550   20.3  44282  1.9
# 30502  45.7725  26.6335   74.3  44282  3.0
# 30503  45.5518  26.4571  110.7  44282  3.2
#
# [30504 rows x 5 columns]

# %% [markdown]
# IMPORTANCE SCORE PENTRU MODELUL DAYS (DATE ROMANIA)

# %%
array = df2.values
X = array[:,0:4]
Y = array[:, 4]
# feature extraction
test = SelectKBest(score_func=f_classif, k= 'all')
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=4)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:4,:])
# Out:
# [ 14.2013  56.0256 862.9582 343.7694]
# [[ 46.5  27.3   9.9   0. ]
#  [ 46.   21.2   9.9  26. ]
#  [ 46.5  27.3   9.9  28. ]
#  [ 44.3  26.3   9.9 170. ]]

# %%
df3 = pd.read_csv('C:/Users/stefa/Downloads/Merge.csv')
df3
# Out:
#            Lat      Lon  Depth   Days  Mag
# 0       57.090 -153.480    0.0      0  8.3
# 1       60.000 -135.000    0.0    100  7.1
# 2       52.000 -160.000    0.0    446  6.6
# 3       51.450 -171.020    0.0    447  7.8
# 4       52.380 -167.450    0.0    448  7.8
# ...        ...      ...    ...    ...  ...
# 363065  16.625  -98.755   35.0  40990  4.0
# 363066  52.788  171.431   48.4  40990  4.5
# 363067  14.083  -92.184   62.4  40990  4.4
# 363068 -61.596  154.288   10.0  40990  5.2
# 363069  -6.950  154.485   52.8  40990  4.6
#
# [363070 rows x 5 columns]

# %% [markdown]
# IMPORTANCE SCORE PENTRU MODELUL DAYS (DATE GLOBALE)

# %%
array = df3.values
X = array[:,0:4]
Y = array[:, 4]
# feature extraction
test = SelectKBest(score_func=f_classif, k= 'all')
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=4)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:4,:])
# Out:
# [40.2004 35.763   6.1618 88.7497]
# [[  57.09 -153.48    0.      0.  ]
#  [  60.   -135.      0.    100.  ]
#  [  52.   -160.      0.    446.  ]
#  [  51.45 -171.02    0.    447.  ]]

# %% [markdown]
# GRAFIC FEATURE IMPORTANCE

# %%
t = pd.read_excel('C:/Users/stefa/Desktop/FI_Days.xlsx')
t
# Out:
#      Model  FI Score    Variabila
# 0   Global     40.20   Latitudine
# 1  Romania     14.20   Latitudine
# 2   Global     35.76  Longitudine
# 3  Romania     56.03  Longitudine
# 4   Global      6.16     Adancime
# 5  Romania    863.00     Adancime
# 6   Global     12.63     Previous
# 7  Romania    211.18     Previous

# %%
#Grafic days
sns.barplot(x = 'Model', y = 'FI Score', data = t, hue = 'Variabila')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='FI Score'>

# %%
#Grafic previous
sns.barplot(x = 'Model', y = 'FI Score', data = t, hue = 'Variabila')
# Out:
# <AxesSubplot:xlabel='Model', ylabel='FI Score'>
